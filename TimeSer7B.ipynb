# %% [markdown]
# # Example: MLE and initial values

# %%
D <- read.csv("https://nmimoto.github.io/datasets/copper.csv")
D1 <- ts(D[,2], start=1)
plot(D1, type="o")
# Out:
# plot without title

# %%
library(forecast)
auto.arima(D1)
# Out:
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Series: D1
# ARIMA(1,0,3) with non-zero mean
#
# Coefficients:
#          ar1      ma1      ma2      ma3    mean
#       0.8695  -0.0925  -0.2958  -0.1809  1.0607
# s.e.  0.0865   0.1129   0.0921   0.0751  0.1590
#
# sigma^2 estimated as 0.4809:  log likelihood=-205.24
# AIC=422.47   AICc=422.91   BIC=442.17

# %%
Arima(D1, order=c(1,0,3))
# Out:
# Series: D1
# ARIMA(1,0,3) with non-zero mean
#
# Coefficients:
#          ar1      ma1      ma2      ma3    mean
#       0.8695  -0.0925  -0.2958  -0.1809  1.0607
# s.e.  0.0865   0.1129   0.0921   0.0751  0.1590
#
# sigma^2 estimated as 0.4809:  log likelihood=-205.24
# AIC=422.47   AICc=422.91   BIC=442.17

# %%
Arima(D1, order=c(1,0,3), method="CSS")
# Out:
# Series: D1
# ARIMA(1,0,3) with non-zero mean
#
# Coefficients:
#          ar1      ma1      ma2      ma3    mean
#       0.8570  -0.0780  -0.2870  -0.1784  1.1006
# s.e.  0.0889   0.1146   0.0916   0.0738  0.1577
#
# sigma^2 estimated as 0.479:  part log likelihood=-205

# %%
Arima(D1, order=c(1,0,3), method="ML", init=c(0.6, -0.1, -0.3, 0.2, 20))
# Out:
# Warning message in sqrt(diag(x$var.coef)):
# “NaNs produced”
# Series: D1
# ARIMA(1,0,3) with non-zero mean
#
# Coefficients:
#          ar1      ma1      ma2     ma3     mean
#       0.9998  -0.3018  -0.3959  0.0291  19.9009
# s.e.     NaN   0.0738   0.0618  0.0741      NaN
#
# sigma^2 estimated as 0.5394:  log likelihood=-219.19
# AIC=450.38   AICc=450.82   BIC=470.08

# %%
Arima(D1, order=c(1,0,3), method="ML", init=c(0.7, -0.5, -0.3, 0.2, 2))
# Out:
# Series: D1
# ARIMA(1,0,3) with non-zero mean
#
# Coefficients:
#          ar1      ma1      ma2      ma3    mean
#       0.8695  -0.0926  -0.2958  -0.1809  1.0606
# s.e.  0.0865   0.1129   0.0921   0.0751  0.1590
#
# sigma^2 estimated as 0.4809:  log likelihood=-205.24
# AIC=422.47   AICc=422.91   BIC=442.17

# %% [markdown]
# # Example: Wave tank data

# %%
D <- read.csv("https://nmimoto.github.io/datasets/wave.csv", header=T)
Wave <- ts(D, start=c(1,1), freq=1)

library(forecast)
plot(Wave)
# Out:
# plot without title

# %%
source('https://nmimoto.github.io/R/TS-00.txt')
Fit1 <- auto.arima(Wave, d=0)
Fit1
# Out:
# Loading required package: zoo
#
#
# Attaching package: ‘zoo’
#
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
# Series: Wave
# ARIMA(3,0,5) with non-zero mean
#
# Coefficients:
#          ar1      ar2     ar3      ma1     ma2     ma3     ma4      ma5
#       1.8624  -1.3719  0.2980  -1.6133  0.0287  0.7688  0.1794  -0.3429
# s.e.  0.1110   0.1670  0.0988   0.1047  0.1540  0.1065  0.1353   0.0645
#          mean
#       -5.0000
# s.e.   0.7079
#
# sigma^2 estimated as 19886:  log likelihood=-2520
# AIC=5060.01   AICc=5060.58   BIC=5099.82

# %%
Randomness.tests(Fit1$resid)
# Out:
#   B-L test H0: the sereis is uncorrelated
#   M-L test H0: the square of the sereis is uncorrelated
#   J-B test H0: the sereis came from Normal distribution
#   SD         : Standard Deviation of the series
#      BL15  BL20  BL25  ML15  ML20  JB SD
# [1,] 0.078 0.174 0.163 0.959 0.774 0  139.579
# Plot with title “”
